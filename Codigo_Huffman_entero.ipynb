# %% [markdown]
# ### Codigo Huffman

# %%
#@title Codificación y decodificación
import pandas as pd
import numpy as np
from collections import Counter
import itertools

s=[]
frase = input("Introduzca una frase:",)

r=pd.Series(list(frase))
s=list(r.value_counts())
s1=list(r.value_counts())

result = [item for items, c in Counter(list(frase)).most_common() for item in [items] * c]

print("Frase organizada:",list(result))
print("Frecuencia de los simbolos:",s)

if len(s)==5:
  s[0]=11
  s[1]=10
  s[2]=str("01")
  s[3]=str("001")
  s[4]=str("000")


if len(s)==6:
  s[0]=11
  s[1]=10
  s[2]=str("011")
  s[3]=str("010")
  s[4]=str("001")
  s[5]=str("000")


if len(s)==7:
  s[0]=11
  s[1]=101
  s[2]=100
  s[3]=str("011")
  s[4]=str("010")
  s[5]=str("001")
  s[6]=str("000")


if len(s)==8:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("010")
  s[6]=str("001")
  s[7]=str("000")


if len(s)==9:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("010")
  s[6]=str("001")
  s[7]=str("0001")
  s[8]=str("0000")


if len(s)==10:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("0011")
  s[5]=str("0010")
  s[6]=str("0011")
  s[7]=str("0010")
  s[8]=str("0001")
  s[9]=str("0000")


if len(s)==11:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("0101")
  s[6]=str("0100")
  s[7]=str("0011")
  s[8]=str("0010")
  s[9]=str("0001")
  s[10]=str("0000")


if len(s)==12:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("0111")
  s[5]=str("0110")
  s[6]=str("0101")
  s[7]=str("0100")
  s[8]=str("0011")
  s[9]=str("0010")
  s[10]=str("0001")
  s[11]=str("0000")


if len(s)==13:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=1001
  s[4]=1000
  s[5]=str("0111")
  s[6]=str("0110")
  s[7]=str("0101")
  s[8]=str("0100")
  s[9]=str("0011")
  s[10]=str("0010")
  s[11]=str("0001")
  s[12]= str("0000")


if len(s)==14:
  s[0]=111
  s[1]=110
  s[2]=1011
  s[3]=1010
  s[4]=1001
  s[5]=1000
  s[6]=str("0111")
  s[7]=str("0110")
  s[8]=str("0101")
  s[9]=str("0100")
  s[10]=str("0011")
  s[11]=str("0010")
  s[12]=str("0001")
  s[13]= str("0000")


if len(s)==15:
  s[0]=111
  s[1]=1101
  s[2]=1100
  s[3]=1011
  s[4]=1010
  s[5]=1001
  s[6]=1000
  s[7]=str("0111")
  s[8]=str("0110")
  s[9]=str("0101")
  s[10]=str("0100")
  s[11]=str("0011")
  s[12]=str("0010")
  s[13]=str("0001")
  s[14]= str("0000")


if len(s)==16:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("0001")
  s[15]= str("0000")


if len(s)==17:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("0001")
  s[15]= str("00001")
  s[16]= str("00000")


if len(s)==18:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("00011")
  s[15]=str("00010")
  s[16]= str("00001")
  s[17]= str("00000")


if len(s)==19:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("00101")
  s[14]=str("00100")
  s[15]=str("00011")
  s[16]=str("00010")
  s[17]= str("00001")
  s[18]= str("00000")


if len(s)==20:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("00111")
  s[13]=str("00110")
  s[14]=str("00101")
  s[15]=str("00100")
  s[16]=str("00011")
  s[17]=str("00010")
  s[18]= str("00001")
  s[19]= str("00000")

a=[]
for i in range(len(s)):
  s[i]==s1[i]
  if s1[i]==1:
    a.append((s[i]))
  if s1[i] > 1:
    for _ in itertools.repeat(s[i], s1[i]):
      a.append(s[i])
print("Frase organizada en binario:",a)

traduction = {result:a for (result,a) in zip(result,a)}

print("Simbolos con su respectivo binario:",traduction)

b=[]
for i in range(len(list(frase))):
  b.append(traduction[list(frase)[i]])

y = "".join(str(e) for e in b)
print("Frase codificada:",y)

print("Tamaño en bits de la frase:",len(frase)*8)
print("Tamaño en bits de la frase codificada:",len(y))

decodification = {a:result for (a,result) in zip(a,result)}

c=[]
for i in range(len(list(b))):
  c.append(decodification[list(b)[i]])

x = "".join(str(e) for e in c)
print("Frase decodificada:",x)
# Out:
# Introduzca una frase:mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmaaaaaaaaaaaaaaaaaaaaaaaaaaattteeeeeeeeeeoooooooooooooooooooorrrrrrrrrppnnnnnnnnnnnnnn
# Frase organizada: ['m', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'o', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 't', 't', 't', 'p', 'p']
# Frecuencia de los simbolos: [30, 27, 20, 14, 10, 9, 3, 2]
# Frase organizada en binario: [111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 111, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 110, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 101, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, '011', '011', '011', '011', '011', '011', '011', '011', '011', '011', '010', '010', '010', '010', '010', '010', '010', '010', '010', '001', '001', '001', '000', '000']
# Simbolos con su respectivo binario: {'m': 111, 'a': 110, 'o': 101, 'n': 100, 'e': '011', 'r': '010', 't': '001', 'p': '000'}
# Frase codificada: 
# Tamaño en bits de la frase: 920
# Tamaño en bits de la frase codificada: 345
# Frase decodificada: mmmmmmmmmmmmmmmmmmmmmmmmmmmmmmaaaaaaaaaaaaaaaaaaaaaaaaaaattteeeeeeeeeeoooooooooooooooooooorrrrrrrrrppnnnnnnnnnnnnnn
