# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Codificación

# %%
import pandas as pd
import numpy as np
from collections import Counter
import itertools

s=[]
frase = input("Introduzca una frase:",)

r=pd.Series(list(frase))
s=list(r.value_counts())
s1=list(r.value_counts())

result = [item for items, c in Counter(list(frase)).most_common() for item in [items] * c]

print(list(result))
print(s)
# Out:
# Introduzca una frase:mmmmateo
# ['m', 'm', 'm', 'm', 'a', 't', 'e', 'o']
# [4, 1, 1, 1, 1]

# %%
len(s)
# Out:
# 5

# %%
s[0] - s[1]
# Out:
# 3

# %%
#@title Huffman


if len(s)==4:
  s[0]=11
  s[1]=10
  s[2]=str("01")
  s[3]=str("00")


if len(s)==5:

  if s[0] - s[1] >= 3:

   s[0]=1
   s[1]=000
   s[2]=str("001")
   s[3]=str("010")
   s[4]=str("011")

  else:

   s[0]=11
   s[1]=10
   s[2]=str("01")
   s[3]=str("001")
   s[4]=str("000")



if len(s)==6:
  s[0]=11
  s[1]=10
  s[2]=str("011")
  s[3]=str("010")
  s[4]=str("001")
  s[5]=str("000")


if len(s)==7:
  s[0]=11
  s[1]=101
  s[2]=100
  s[3]=str("011")
  s[4]=str("010")
  s[5]=str("001")
  s[6]=str("000")


if len(s)==8:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("010")
  s[6]=str("001")
  s[7]=str("000")


if len(s)==9:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("010")
  s[6]=str("001")
  s[7]=str("0001")
  s[8]=str("0000")


if len(s)==10:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("0011")
  s[5]=str("0010")
  s[6]=str("0011")
  s[7]=str("0010")
  s[8]=str("0001")
  s[9]=str("0000")


if len(s)==11:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("011")
  s[5]=str("0101")
  s[6]=str("0100")
  s[7]=str("0011")
  s[8]=str("0010")
  s[9]=str("0001")
  s[10]=str("0000")


if len(s)==12:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=100
  s[4]=str("0111")
  s[5]=str("0110")
  s[6]=str("0101")
  s[7]=str("0100")
  s[8]=str("0011")
  s[9]=str("0010")
  s[10]=str("0001")
  s[11]=str("0000")


if len(s)==13:
  s[0]=111
  s[1]=110
  s[2]=101
  s[3]=1001
  s[4]=1000
  s[5]=str("0111")
  s[6]=str("0110")
  s[7]=str("0101")
  s[8]=str("0100")
  s[9]=str("0011")
  s[10]=str("0010")
  s[11]=str("0001")
  s[12]= str("0000")


if len(s)==14:
  s[0]=111
  s[1]=110
  s[2]=1011
  s[3]=1010
  s[4]=1001
  s[5]=1000
  s[6]=str("0111")
  s[7]=str("0110")
  s[8]=str("0101")
  s[9]=str("0100")
  s[10]=str("0011")
  s[11]=str("0010")
  s[12]=str("0001")
  s[13]= str("0000")


if len(s)==15:
  s[0]=111
  s[1]=1101
  s[2]=1100
  s[3]=1011
  s[4]=1010
  s[5]=1001
  s[6]=1000
  s[7]=str("0111")
  s[8]=str("0110")
  s[9]=str("0101")
  s[10]=str("0100")
  s[11]=str("0011")
  s[12]=str("0010")
  s[13]=str("0001")
  s[14]= str("0000")


if len(s)==16:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("0001")
  s[15]= str("0000")


if len(s)==17:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("0001")
  s[15]= str("00001")
  s[16]= str("00000")


if len(s)==18:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("0010")
  s[14]=str("00011")
  s[15]=str("00010")
  s[16]= str("00001")
  s[17]= str("00000")


if len(s)==19:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("0011")
  s[13]=str("00101")
  s[14]=str("00100")
  s[15]=str("00011")
  s[16]=str("00010")
  s[17]= str("00001")
  s[18]= str("00000")


if len(s)==20:
  s[0]=1111
  s[1]=1110
  s[2]=1101
  s[3]=1100
  s[4]=1011
  s[5]=1010
  s[6]=1001
  s[7]=1000
  s[8]=str("0111")
  s[9]=str("0110")
  s[10]=str("0101")
  s[11]=str("0100")
  s[12]=str("00111")
  s[13]=str("00110")
  s[14]=str("00101")
  s[15]=str("00100")
  s[16]=str("00011")
  s[17]=str("00010")
  s[18]=str("00001")
  s[19]=str("00000")

# %%
print(s)
print(s1)
# Out:
# [1, 0, '001', '010', '011']
# [4, 1, 1, 1, 1]

# %%
a=[]
for i in range(len(s)):
  s[i]==s1[i]
  if s1[i]==1:
    a.append((s[i]))
  if s1[i] > 1:
    for _ in itertools.repeat(s[i], s1[i]):
      a.append(s[i])
print(a)
# Out:
# [1, 1, 1, 1, 0, '001', '010', '011']

# %%
print(list(result))
print(a)
# Out:
# ['m', 'm', 'm', 'm', 'a', 't', 'e', 'o']
# [1, 1, 1, 1, 0, '001', '010', '011']

# %%
traduction = {result:a for (result,a) in zip(result,a)}

print(traduction)
# Out:
# {'m': 1, 'a': 0, 't': '001', 'e': '010', 'o': '011'}

# %%
b=[]
for i in range(len(list(frase))):
  b.append(traduction[list(frase)[i]])

print(list(frase))
print(str(b))
# Out:
# ['m', 'm', 'm', 'm', 'a', 't', 'e', 'o']
# [1, 1, 1, 1, 0, '001', '010', '011']

# %%
y = "".join(str(e) for e in b)
print(y)
# Out:
# 11110001010011

# %%
len(y)
# Out:
# 14

# %%
len(frase)*8
# Out:
# 64

# %% [markdown]
# ### Decodificación

# %%
decodification = {a:result for (a,result) in zip(a,result)}

print(decodification)
# Out:
# {111: 'i', 110: 'v', 101: ' ', 100: 'l', '011': 'u', '0101': 'a', '0100': 'm', '0011': 't', '0010': 'o', '0001': 's', '0000': 'w'}

# %%
c=[]
for i in range(len(list(b))):
  c.append(decodification[list(b)[i]])

print(str(c))
# Out:
# ['q', 'q', 'w', 'w', 's', 's', 'e', 'e', 'd', 'd', 'k', 'a', 'l', 'a', 'p', '1', '9', '3', '9', '8', '5', ' ', ' ', ' ']

# %%
x = "".join(str(e) for e in c)
print(x)
# Out:
# qqwwsseeddkalap193985
